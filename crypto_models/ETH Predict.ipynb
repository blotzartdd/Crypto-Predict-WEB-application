# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional, LSTM, Activation
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
csv_path = 'https://query1.finance.yahoo.com/v7/finance/download/ETH-USD?period1=1445472000&period2=1650585600&interval=1d&events=history&includeAdjustedClose=true'
df = pd.read_csv(csv_path, parse_dates=['Date'])
df = df.sort_values('Date')

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2017-11-09   308.644989   329.451996   307.056000   320.884003
# 1    2017-11-10   320.670990   324.717987   294.541992   299.252991
# 2    2017-11-11   298.585999   319.453003   298.191986   314.681000
# 3    2017-11-12   314.690002   319.153015   298.513000   307.907990
# 4    2017-11-13   307.024994   328.415009   307.024994   316.716003
# ...         ...          ...          ...          ...          ...
# 1621 2022-04-18  2993.483887  3062.520996  2893.912842  3057.606689
# 1622 2022-04-19  3057.570313  3125.084229  3035.535156  3104.106445
# 1623 2022-04-20  3103.935059  3157.885742  3045.288330  3077.745850
# 1624 2022-04-21  3077.829346  3173.451416  2962.410400  2987.480713
# 1625 2022-04-22  2986.938721  3024.854492  2942.358643  2964.835693
#
#         Adj Close       Volume
# 0      320.884003    893249984
# 1      299.252991    885985984
# 2      314.681000    842300992
# 3      307.907990   1613479936
# 4      316.716003   1041889984
# ...           ...          ...
# 1621  3057.606689  18629381299
# 1622  3104.106445  14156035096
# 1623  3077.745850  15547362265
# 1624  2987.480713  20783591093
# 1625  2964.835693  16782795477
#
# [1626 rows x 7 columns]

# %%
scaler = MinMaxScaler()

close_price = df.Close.values.reshape(-1, 1)

scaled_close = scaler.fit_transform(close_price)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaled_close = scaled_close[~np.isnan(scaled_close)]
scaled_close = scaled_close.reshape(-1, 1)

# %%
SEQ_LEN = 100

def dataset_generator_lstm(dataset, look_back=5):
    X_data, y_data = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back), 0]
        X_data.append(window_size_x)
        y_data.append(dataset[i + look_back, 0])
    return np.array(X_data), np.array(y_data)

def to_sequences(data, seq_len):
    d = []

    for index in range(len(data) - seq_len):
        d.append(data[index: index + seq_len])

    return np.array(d)

def preprocess(data_raw, seq_len, train_split):

    data = to_sequences(data_raw, seq_len)

    num_train = int(train_split * data.shape[0])

    X_train = data[:num_train, :-1, :]
    y_train = data[:num_train, -1, :]

    X_test = data[num_train:, :-1, :]
    y_test = data[num_train:, -1, :]

    return X_train, y_train, X_test, y_test


X_train, y_train, X_test, y_test = preprocess(scaled_close, SEQ_LEN, train_split = 0.95)

# %%
DROPOUT = 0.2
WINDOW_SIZE = SEQ_LEN - 1

model = Sequential()

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True),
  input_shape=(WINDOW_SIZE, X_train.shape[-1])
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM((WINDOW_SIZE * 2), return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=False)
))

model.add(Dense(units=1))

model.add(Activation('linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 99, 198)          80784
#  l)
#
#  dropout (Dropout)           (None, 99, 198)           0
#
#  bidirectional_1 (Bidirectio  (None, 99, 396)          630432
#  nal)
#
#  dropout_1 (Dropout)         (None, 99, 396)           0
#
#  bidirectional_2 (Bidirectio  (None, 99, 198)          393624
#  nal)
#
#  dropout_2 (Dropout)         (None, 99, 198)           0
#
#  bidirectional_3 (Bidirectio  (None, 198)              236808
#  nal)
#
#  dense (Dense)               (None, 1)                 199
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,341,847
# Trainable params: 1,341,847
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

BATCH_SIZE = 64

checkpoint_path = 'ETH_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

callbacks = [checkpoint]
model.compile(
    loss='mean_squared_error',
    optimizer='adam'
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=BATCH_SIZE,
    shuffle=False,
    validation_split=0.1,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 00001: val_loss improved from inf to 0.01629, saving model to ETH_model.hdf5
# 21/21 [==============================] - 10s 165ms/step - loss: 0.0144 - val_loss: 0.0163
# Epoch 2/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0293
# Epoch 00002: val_loss did not improve from 0.01629
# 21/21 [==============================] - 1s 62ms/step - loss: 0.0313 - val_loss: 0.0262
# Epoch 3/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0362
# Epoch 00003: val_loss improved from 0.01629 to 0.00580, saving model to ETH_model.hdf5
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0377 - val_loss: 0.0058
# Epoch 4/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0814
# Epoch 00004: val_loss did not improve from 0.00580
# 21/21 [==============================] - 1s 61ms/step - loss: 0.0873 - val_loss: 0.4700
# Epoch 5/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0167
# Epoch 00005: val_loss did not improve from 0.00580
# 21/21 [==============================] - 1s 62ms/step - loss: 0.0188 - val_loss: 0.0865
# Epoch 6/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0354
# Epoch 00006: val_loss did not improve from 0.00580
# 21/21 [==============================] - 1s 65ms/step - loss: 0.0380 - val_loss: 0.1764
# Epoch 7/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0227
# Epoch 00007: val_loss improved from 0.00580 to 0.00532, saving model to ETH_model.hdf5
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0231 - val_loss: 0.0053
# Epoch 8/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0440
# Epoch 00008: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0451 - val_loss: 0.1579
# Epoch 9/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0286
# Epoch 00009: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0335 - val_loss: 0.3376
# Epoch 10/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0296
# Epoch 00010: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 65ms/step - loss: 0.0330 - val_loss: 0.2463
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 00011: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 64ms/step - loss: 0.0370 - val_loss: 0.1805
# Epoch 12/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0083
# Epoch 00012: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 63ms/step - loss: 0.0083 - val_loss: 0.0093
# Epoch 13/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0088
# Epoch 00013: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 14/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 00014: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0215 - val_loss: 0.1876
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 00015: val_loss did not improve from 0.00532
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0088 - val_loss: 0.0263
# Epoch 16/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0062
# Epoch 00016: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 17/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0088
# Epoch 00017: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0106 - val_loss: 0.1205
# Epoch 18/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0048
# Epoch 00018: val_loss did not improve from 0.00532
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0052 - val_loss: 0.0272
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00019: val_loss did not improve from 0.00532
# 21/21 [==============================] - 2s 81ms/step - loss: 0.0036 - val_loss: 0.0056
# Epoch 20/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 00020: val_loss did not improve from 0.00532
# 21/21 [==============================] - 2s 81ms/step - loss: 0.0027 - val_loss: 0.0125
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00021: val_loss improved from 0.00532 to 0.00483, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 22/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 00022: val_loss did not improve from 0.00483
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00023: val_loss improved from 0.00483 to 0.00395, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 24/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0022
# Epoch 00024: val_loss did not improve from 0.00395
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00025: val_loss improved from 0.00395 to 0.00384, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 77ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 26/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0015
# Epoch 00026: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0016 - val_loss: 0.0055
# Epoch 27/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0016
# Epoch 00027: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 00028: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00029: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0018 - val_loss: 0.0039
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00030: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0019 - val_loss: 0.0119
# Epoch 31/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 00031: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 71ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00032: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0031 - val_loss: 0.0247
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00033: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 77ms/step - loss: 0.0031 - val_loss: 0.0041
# Epoch 34/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0029
# Epoch 00034: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0034 - val_loss: 0.0299
# Epoch 35/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0028
# Epoch 00035: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0028 - val_loss: 0.0041
# Epoch 36/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 00036: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0024 - val_loss: 0.0203
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00037: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00038: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0023 - val_loss: 0.0176
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00039: val_loss did not improve from 0.00384
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00040: val_loss did not improve from 0.00384
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0025 - val_loss: 0.0170
# Epoch 41/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 00041: val_loss improved from 0.00384 to 0.00372, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 80ms/step - loss: 0.0026 - val_loss: 0.0037
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00042: val_loss did not improve from 0.00372
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0025 - val_loss: 0.0185
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00043: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 44/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 00044: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0029 - val_loss: 0.0238
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00045: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00046: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0026 - val_loss: 0.0218
# Epoch 47/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0026
# Epoch 00047: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 48/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 00048: val_loss did not improve from 0.00372
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0022 - val_loss: 0.0189
# Epoch 49/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0024
# Epoch 00049: val_loss improved from 0.00372 to 0.00366, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 77ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00050: val_loss did not improve from 0.00366
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0022 - val_loss: 0.0183
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00051: val_loss did not improve from 0.00366
# 21/21 [==============================] - 2s 92ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00052: val_loss did not improve from 0.00366
# 21/21 [==============================] - 2s 91ms/step - loss: 0.0022 - val_loss: 0.0191
# Epoch 53/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00053: val_loss improved from 0.00366 to 0.00359, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 89ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 54/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00054: val_loss did not improve from 0.00359
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0023 - val_loss: 0.0182
# Epoch 55/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 00055: val_loss improved from 0.00359 to 0.00349, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 88ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 56/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00056: val_loss did not improve from 0.00349
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0023 - val_loss: 0.0190
# Epoch 57/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00057: val_loss improved from 0.00349 to 0.00347, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 77ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 58/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00058: val_loss did not improve from 0.00347
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0023 - val_loss: 0.0196
# Epoch 59/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00059: val_loss improved from 0.00347 to 0.00343, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 98ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 60/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00060: val_loss did not improve from 0.00343
# 21/21 [==============================] - 2s 107ms/step - loss: 0.0022 - val_loss: 0.0214
# Epoch 61/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00061: val_loss did not improve from 0.00343
# 21/21 [==============================] - 2s 89ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 62/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 00062: val_loss did not improve from 0.00343
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0203
# Epoch 63/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00063: val_loss did not improve from 0.00343
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 64/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00064: val_loss did not improve from 0.00343
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0021 - val_loss: 0.0180
# Epoch 65/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00065: val_loss improved from 0.00343 to 0.00337, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 80ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 66/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00066: val_loss did not improve from 0.00337
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0023 - val_loss: 0.0205
# Epoch 67/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00067: val_loss improved from 0.00337 to 0.00335, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 82ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 68/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00068: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0219
# Epoch 69/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00069: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 83ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 70/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0021
# Epoch 00070: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0024 - val_loss: 0.0216
# Epoch 71/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0025
# Epoch 00071: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 72/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00072: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0022 - val_loss: 0.0214
# Epoch 73/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00073: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 74/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0020
# Epoch 00074: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0023 - val_loss: 0.0222
# Epoch 75/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00075: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 76/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00076: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0021 - val_loss: 0.0205
# Epoch 77/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 00077: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 72ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 78/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00078: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0022 - val_loss: 0.0214
# Epoch 79/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00079: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 80/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00080: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0022 - val_loss: 0.0221
# Epoch 81/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00081: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 82/100
# 20/21 [===========================>..] - ETA: 0s - loss: 0.0019
# Epoch 00082: val_loss did not improve from 0.00335
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0022 - val_loss: 0.0218
# Epoch 83/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00083: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 84/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00084: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0021 - val_loss: 0.0213
# Epoch 85/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00085: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 75ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 86/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00086: val_loss did not improve from 0.00335
# 21/21 [==============================] - 2s 79ms/step - loss: 0.0019 - val_loss: 0.0196
# Epoch 87/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00087: val_loss improved from 0.00335 to 0.00334, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 81ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 88/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00088: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0022 - val_loss: 0.0218
# Epoch 89/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00089: val_loss improved from 0.00334 to 0.00334, saving model to ETH_model.hdf5
# 21/21 [==============================] - 2s 79ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 90/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00090: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 76ms/step - loss: 0.0023 - val_loss: 0.0238
# Epoch 91/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00091: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 76ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 92/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00092: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 76ms/step - loss: 0.0023 - val_loss: 0.0244
# Epoch 93/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00093: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 94/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00094: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0022 - val_loss: 0.0233
# Epoch 95/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00095: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 72ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 96/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00096: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0021 - val_loss: 0.0227
# Epoch 97/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00097: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 98/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00098: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0020 - val_loss: 0.0218
# Epoch 99/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00099: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 74ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 100/100
# 21/21 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00100: val_loss did not improve from 0.00334
# 21/21 [==============================] - 2s 73ms/step - loss: 0.0021 - val_loss: 0.0225

# %%
loss = history.history['loss']
epoch_count = range(1, len(loss) + 1)
plt.figure(figsize=(12,8))
plt.plot(epoch_count, loss, 'r--')
plt.legend(['Training Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
y_pred = model_from_saved_checkpoint.predict(X_test)

# %%
y_pred_transformed = scaler.inverse_transform(y_pred)
y_test_transformed = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(12, 8))
plt.plot(y_test_transformed, color='green', label='Real')
plt.plot(y_pred_transformed, color='red', label='Prediction')
plt.title('Ethereum Price Prediction')
plt.legend()
plt.show()

# %%
mean_absolute_error(y_pred_transformed, y_test_transformed)
# Out:
# 247.02762909273537
