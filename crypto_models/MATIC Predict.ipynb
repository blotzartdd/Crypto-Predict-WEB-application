# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional, LSTM, Activation
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
csv_path = 'https://query1.finance.yahoo.com/v7/finance/download/MATIC-USD?period1=1548720000&period2=1650672000&interval=1d&events=history&includeAdjustedClose=true'
df = pd.read_csv(csv_path, parse_dates=['Date'])
df = df.sort_values('Date')

# %%
df
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 0    2019-04-28  0.004521  0.004545  0.004317  0.004421   0.004421     8408136
# 1    2019-04-29  0.004418  0.004492  0.003471  0.003471   0.003471     8267044
# 2    2019-04-30  0.003462  0.005078  0.003458  0.004478   0.004478    25072706
# 3    2019-05-01  0.004440  0.004673  0.004071  0.004374   0.004374    10567352
# 4    2019-05-02  0.004366  0.004700  0.004096  0.004198   0.004198     6714908
# ...         ...       ...       ...       ...       ...        ...         ...
# 1087 2022-04-19  1.421118  1.447452  1.396778  1.428176   1.428176   630841720
# 1088 2022-04-20  1.428233  1.463450  1.401330  1.417744   1.417744   648103958
# 1089 2022-04-21  1.417712  1.465750  1.368370  1.379862   1.379862   652619938
# 1090 2022-04-22  1.379697  1.496747  1.374800  1.399139   1.399139  1281222594
# 1091 2022-04-23  1.398472  1.405849  1.351056  1.371737   1.371737  1128169472
#
# [1092 rows x 7 columns]

# %%
scaler = MinMaxScaler()

close_price = df.Close.values.reshape(-1, 1)

scaled_close = scaler.fit_transform(close_price)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaled_close = scaled_close[~np.isnan(scaled_close)]
scaled_close = scaled_close.reshape(-1, 1)

# %%
SEQ_LEN = 100

def dataset_generator_lstm(dataset, look_back=5):
    X_data, y_data = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back), 0]
        X_data.append(window_size_x)
        y_data.append(dataset[i + look_back, 0])
    return np.array(X_data), np.array(y_data)

def to_sequences(data, seq_len):
    d = []

    for index in range(len(data) - seq_len):
        d.append(data[index: index + seq_len])

    return np.array(d)

def preprocess(data_raw, seq_len, train_split):

    data = to_sequences(data_raw, seq_len)

    num_train = int(train_split * data.shape[0])

    X_train = data[:num_train, :-1, :]
    y_train = data[:num_train, -1, :]

    X_test = data[num_train:, :-1, :]
    y_test = data[num_train:, -1, :]

    return X_train, y_train, X_test, y_test


X_train, y_train, X_test, y_test = preprocess(scaled_close, SEQ_LEN, train_split = 0.95)

# %%
DROPOUT = 0.2
WINDOW_SIZE = SEQ_LEN - 1

model = Sequential()

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True),
  input_shape=(WINDOW_SIZE, X_train.shape[-1])
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM((WINDOW_SIZE * 2), return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=False)
))

model.add(Dense(units=1))

model.add(Activation('linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 99, 198)          80784
#  l)
#
#  dropout (Dropout)           (None, 99, 198)           0
#
#  bidirectional_1 (Bidirectio  (None, 99, 396)          630432
#  nal)
#
#  dropout_1 (Dropout)         (None, 99, 396)           0
#
#  bidirectional_2 (Bidirectio  (None, 99, 198)          393624
#  nal)
#
#  dropout_2 (Dropout)         (None, 99, 198)           0
#
#  bidirectional_3 (Bidirectio  (None, 198)              236808
#  nal)
#
#  dense (Dense)               (None, 1)                 199
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,341,847
# Trainable params: 1,341,847
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

BATCH_SIZE = 64

checkpoint_path = 'MATIC_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

callbacks = [checkpoint]
model.compile(
    loss='mean_squared_error',
    optimizer='adam'
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=BATCH_SIZE,
    shuffle=False,
    validation_split=0.1,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 00001: val_loss improved from inf to 0.04405, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 19s 307ms/step - loss: 0.0211 - val_loss: 0.0440
# Epoch 2/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0491
# Epoch 00002: val_loss improved from 0.04405 to 0.02251, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0496 - val_loss: 0.0225
# Epoch 3/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0198
# Epoch 00003: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 83ms/step - loss: 0.0195 - val_loss: 0.0382
# Epoch 4/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0526
# Epoch 00004: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0517 - val_loss: 0.0795
# Epoch 5/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.1054
# Epoch 00005: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 85ms/step - loss: 0.1084 - val_loss: 0.3063
# Epoch 6/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 00006: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 86ms/step - loss: 0.0225 - val_loss: 0.0699
# Epoch 7/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0205
# Epoch 00007: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0201 - val_loss: 0.0395
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0289
# Epoch 00008: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0289 - val_loss: 0.2146
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0222
# Epoch 00009: val_loss did not improve from 0.02251
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0222 - val_loss: 0.1042
# Epoch 10/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 00010: val_loss improved from 0.02251 to 0.01417, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0027 - val_loss: 0.0142
# Epoch 11/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 00011: val_loss did not improve from 0.01417
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0027 - val_loss: 0.0176
# Epoch 12/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 00012: val_loss did not improve from 0.01417
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0031 - val_loss: 0.0261
# Epoch 13/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 00013: val_loss did not improve from 0.01417
# 14/14 [==============================] - 1s 81ms/step - loss: 0.0033 - val_loss: 0.0157
# Epoch 14/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0031
# Epoch 00014: val_loss did not improve from 0.01417
# 14/14 [==============================] - 1s 84ms/step - loss: 0.0031 - val_loss: 0.0191
# Epoch 15/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00015: val_loss improved from 0.01417 to 0.01409, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0024 - val_loss: 0.0141
# Epoch 16/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 00016: val_loss did not improve from 0.01409
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0019 - val_loss: 0.0166
# Epoch 17/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 00017: val_loss improved from 0.01409 to 0.01407, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0017 - val_loss: 0.0141
# Epoch 18/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 00018: val_loss did not improve from 0.01407
# 14/14 [==============================] - 1s 82ms/step - loss: 0.0017 - val_loss: 0.0160
# Epoch 19/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0017
# Epoch 00019: val_loss improved from 0.01407 to 0.01341, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0017 - val_loss: 0.0134
# Epoch 20/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 00020: val_loss did not improve from 0.01341
# 14/14 [==============================] - 1s 80ms/step - loss: 0.0018 - val_loss: 0.0163
# Epoch 21/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 00021: val_loss improved from 0.01341 to 0.01266, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0019 - val_loss: 0.0127
# Epoch 22/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00022: val_loss did not improve from 0.01266
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0021 - val_loss: 0.0185
# Epoch 23/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00023: val_loss improved from 0.01266 to 0.01212, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0024 - val_loss: 0.0121
# Epoch 24/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00024: val_loss did not improve from 0.01212
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0033 - val_loss: 0.0260
# Epoch 25/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00025: val_loss improved from 0.01212 to 0.01132, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0032 - val_loss: 0.0113
# Epoch 26/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00026: val_loss did not improve from 0.01132
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0046 - val_loss: 0.0362
# Epoch 27/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00027: val_loss improved from 0.01132 to 0.01102, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0029 - val_loss: 0.0110
# Epoch 28/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00028: val_loss did not improve from 0.01102
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0027 - val_loss: 0.0238
# Epoch 29/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00029: val_loss did not improve from 0.01102
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0025 - val_loss: 0.0120
# Epoch 30/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 00030: val_loss did not improve from 0.01102
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0026 - val_loss: 0.0174
# Epoch 31/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 00031: val_loss did not improve from 0.01102
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0023 - val_loss: 0.0112
# Epoch 32/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0020
# Epoch 00032: val_loss did not improve from 0.01102
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0020 - val_loss: 0.0149
# Epoch 33/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0018
# Epoch 00033: val_loss improved from 0.01102 to 0.01063, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0018 - val_loss: 0.0106
# Epoch 34/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00034: val_loss did not improve from 0.01063
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0018 - val_loss: 0.0158
# Epoch 35/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 00035: val_loss improved from 0.01063 to 0.01017, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0019 - val_loss: 0.0102
# Epoch 36/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 00036: val_loss did not improve from 0.01017
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0022 - val_loss: 0.0187
# Epoch 37/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 00037: val_loss improved from 0.01017 to 0.00971, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0023 - val_loss: 0.0097
# Epoch 38/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00038: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0030 - val_loss: 0.0243
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00039: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0028 - val_loss: 0.0098
# Epoch 40/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00040: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0033 - val_loss: 0.0285
# Epoch 41/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00041: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0026 - val_loss: 0.0101
# Epoch 42/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00042: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0025 - val_loss: 0.0231
# Epoch 43/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00043: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0024 - val_loss: 0.0105
# Epoch 44/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00044: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0024 - val_loss: 0.0197
# Epoch 45/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00045: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0026 - val_loss: 0.0105
# Epoch 46/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00046: val_loss did not improve from 0.00971
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0026 - val_loss: 0.0168
# Epoch 47/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00047: val_loss improved from 0.00971 to 0.00964, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 2s 110ms/step - loss: 0.0024 - val_loss: 0.0096
# Epoch 48/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00048: val_loss did not improve from 0.00964
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0022 - val_loss: 0.0165
# Epoch 49/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00049: val_loss improved from 0.00964 to 0.00920, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 106ms/step - loss: 0.0021 - val_loss: 0.0092
# Epoch 50/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00050: val_loss did not improve from 0.00920
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0025 - val_loss: 0.0203
# Epoch 51/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00051: val_loss improved from 0.00920 to 0.00918, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 2s 113ms/step - loss: 0.0025 - val_loss: 0.0092
# Epoch 52/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00052: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0031 - val_loss: 0.0252
# Epoch 53/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00053: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0026 - val_loss: 0.0093
# Epoch 54/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00054: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0025 - val_loss: 0.0234
# Epoch 55/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00055: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0022 - val_loss: 0.0099
# Epoch 56/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 00056: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 102ms/step - loss: 0.0021 - val_loss: 0.0199
# Epoch 57/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 00057: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 87ms/step - loss: 0.0021 - val_loss: 0.0100
# Epoch 58/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0021
# Epoch 00058: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0021 - val_loss: 0.0183
# Epoch 59/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00059: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 60/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0022
# Epoch 00060: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 90ms/step - loss: 0.0022 - val_loss: 0.0172
# Epoch 61/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 00061: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 92ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 62/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 00062: val_loss did not improve from 0.00918
# 14/14 [==============================] - 1s 88ms/step - loss: 0.0024 - val_loss: 0.0185
# Epoch 63/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00063: val_loss improved from 0.00918 to 0.00898, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0024 - val_loss: 0.0090
# Epoch 64/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0026
# Epoch 00064: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 89ms/step - loss: 0.0027 - val_loss: 0.0225
# Epoch 65/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00065: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0024 - val_loss: 0.0090
# Epoch 66/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 00066: val_loss did not improve from 0.00898
# 14/14 [==============================] - 2s 160ms/step - loss: 0.0026 - val_loss: 0.0237
# Epoch 67/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00067: val_loss did not improve from 0.00898
# 14/14 [==============================] - 2s 124ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 68/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00068: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0022 - val_loss: 0.0210
# Epoch 69/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00069: val_loss did not improve from 0.00898
# 14/14 [==============================] - 2s 109ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 70/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00070: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0020 - val_loss: 0.0199
# Epoch 71/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00071: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 108ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 72/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00072: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0019 - val_loss: 0.0187
# Epoch 73/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00073: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0021 - val_loss: 0.0096
# Epoch 74/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00074: val_loss did not improve from 0.00898
# 14/14 [==============================] - 2s 108ms/step - loss: 0.0021 - val_loss: 0.0183
# Epoch 75/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00075: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0022 - val_loss: 0.0094
# Epoch 76/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00076: val_loss did not improve from 0.00898
# 14/14 [==============================] - 2s 110ms/step - loss: 0.0023 - val_loss: 0.0177
# Epoch 77/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00077: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 104ms/step - loss: 0.0024 - val_loss: 0.0092
# Epoch 78/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00078: val_loss did not improve from 0.00898
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0025 - val_loss: 0.0195
# Epoch 79/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0025
# Epoch 00079: val_loss improved from 0.00898 to 0.00890, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 101ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 80/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0027
# Epoch 00080: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0028 - val_loss: 0.0243
# Epoch 81/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00081: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0025 - val_loss: 0.0091
# Epoch 82/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0024
# Epoch 00082: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0025 - val_loss: 0.0239
# Epoch 83/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00083: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0023 - val_loss: 0.0096
# Epoch 84/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00084: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 91ms/step - loss: 0.0022 - val_loss: 0.0220
# Epoch 85/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00085: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0022 - val_loss: 0.0100
# Epoch 86/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00086: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0021 - val_loss: 0.0199
# Epoch 87/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00087: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 99ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 88/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00088: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 96ms/step - loss: 0.0018 - val_loss: 0.0170
# Epoch 89/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0019
# Epoch 00089: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0019 - val_loss: 0.0096
# Epoch 90/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00090: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0017 - val_loss: 0.0159
# Epoch 91/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00091: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0018 - val_loss: 0.0091
# Epoch 92/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00092: val_loss did not improve from 0.00890
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0018 - val_loss: 0.0165
# Epoch 93/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00093: val_loss improved from 0.00890 to 0.00875, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 105ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 94/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 00094: val_loss did not improve from 0.00875
# 14/14 [==============================] - 1s 97ms/step - loss: 0.0021 - val_loss: 0.0191
# Epoch 95/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.0023
# Epoch 00095: val_loss improved from 0.00875 to 0.00856, saving model to MATIC_model.hdf5
# 14/14 [==============================] - 1s 103ms/step - loss: 0.0023 - val_loss: 0.0086
# Epoch 96/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 00096: val_loss did not improve from 0.00856
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0025 - val_loss: 0.0225
# Epoch 97/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00097: val_loss did not improve from 0.00856
# 14/14 [==============================] - 1s 100ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 98/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00098: val_loss did not improve from 0.00856
# 14/14 [==============================] - 1s 98ms/step - loss: 0.0024 - val_loss: 0.0231
# Epoch 99/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 00099: val_loss did not improve from 0.00856
# 14/14 [==============================] - 1s 95ms/step - loss: 0.0023 - val_loss: 0.0094
# Epoch 100/100
# 14/14 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00100: val_loss did not improve from 0.00856
# 14/14 [==============================] - 2s 112ms/step - loss: 0.0022 - val_loss: 0.0224

# %%
loss = history.history['loss']
epoch_count = range(1, len(loss) + 1)
plt.figure(figsize=(12,8))
plt.plot(epoch_count, loss, 'r--')
plt.legend(['Training Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
y_pred = model_from_saved_checkpoint.predict(X_test)

# %%
y_pred_transformed = scaler.inverse_transform(y_pred)
y_test_transformed = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(12, 8))
plt.plot(y_test_transformed, color='green', label='Real')
plt.plot(y_pred_transformed, color='red', label='Prediction')
plt.title('Polygon Price Prediction')
plt.legend()
plt.show()

# %%
mean_absolute_error(y_pred_transformed, y_test_transformed)
# Out:
# 0.08888274902801514
