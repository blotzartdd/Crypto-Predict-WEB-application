# %%
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional, LSTM, Activation
from tensorflow.compat.v1.keras.layers import CuDNNLSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
csv_path = 'https://query1.finance.yahoo.com/v7/finance/download/SOL-USD?period1=1548720000&period2=1650672000&interval=1d&events=history&includeAdjustedClose=true'
df = pd.read_csv(csv_path, parse_dates=['Date'])
df = df.sort_values('Date')

# %%
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-04-10    0.832005    1.313487    0.694187    0.951054    0.951054
# 1   2020-04-11    0.951054    1.049073    0.765020    0.776819    0.776819
# 2   2020-04-12    0.785448    0.956670    0.762426    0.882507    0.882507
# 3   2020-04-13    0.890760    0.891603    0.773976    0.777832    0.777832
# 4   2020-04-14    0.777832    0.796472    0.628169    0.661925    0.661925
# ..         ...         ...         ...         ...         ...         ...
# 739 2022-04-19  102.202385  108.582031  101.301727  108.582031  108.582031
# 740 2022-04-20  108.602196  110.722977  104.772659  105.497002  105.497002
# 741 2022-04-21  105.497673  109.765327  100.767151  101.776138  101.776138
# 742 2022-04-22  101.757423  103.498146   99.579430  100.612053  100.612053
# 743 2022-04-23  100.630371  100.776001   98.781570  100.776001  100.776001
#
#          Volume
# 0      87364276
# 1      43862444
# 2      38736897
# 3      18211285
# 4      16747614
# ..          ...
# 739  1711909607
# 740  1761531528
# 741  1838571747
# 742  1274793594
# 743  1215289856
#
# [744 rows x 7 columns]

# %%
scaler = MinMaxScaler()

close_price = df.Close.values.reshape(-1, 1)

scaled_close = scaler.fit_transform(close_price)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
scaled_close = scaled_close[~np.isnan(scaled_close)]
scaled_close = scaled_close.reshape(-1, 1)

# %%
SEQ_LEN = 100

def dataset_generator_lstm(dataset, look_back=5):
    X_data, y_data = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back), 0]
        X_data.append(window_size_x)
        y_data.append(dataset[i + look_back, 0])
    return np.array(X_data), np.array(y_data)

def to_sequences(data, seq_len):
    d = []

    for index in range(len(data) - seq_len):
        d.append(data[index: index + seq_len])

    return np.array(d)

def preprocess(data_raw, seq_len, train_split):

    data = to_sequences(data_raw, seq_len)

    num_train = int(train_split * data.shape[0])

    X_train = data[:num_train, :-1, :]
    y_train = data[:num_train, -1, :]

    X_test = data[num_train:, :-1, :]
    y_test = data[num_train:, -1, :]

    return X_train, y_train, X_test, y_test


X_train, y_train, X_test, y_test = preprocess(scaled_close, SEQ_LEN, train_split = 0.95)

# %%
DROPOUT = 0.2
WINDOW_SIZE = SEQ_LEN - 1

model = Sequential()

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True),
  input_shape=(WINDOW_SIZE, X_train.shape[-1])
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM((WINDOW_SIZE * 2), return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=True)
))
model.add(Dropout(rate=DROPOUT))

model.add(Bidirectional(
  CuDNNLSTM(WINDOW_SIZE, return_sequences=False)
))

model.add(Dense(units=1))

model.add(Activation('linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 99, 198)          80784
#  l)
#
#  dropout (Dropout)           (None, 99, 198)           0
#
#  bidirectional_1 (Bidirectio  (None, 99, 396)          630432
#  nal)
#
#  dropout_1 (Dropout)         (None, 99, 396)           0
#
#  bidirectional_2 (Bidirectio  (None, 99, 198)          393624
#  nal)
#
#  dropout_2 (Dropout)         (None, 99, 198)           0
#
#  bidirectional_3 (Bidirectio  (None, 198)              236808
#  nal)
#
#  dense (Dense)               (None, 1)                 199
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 1,341,847
# Trainable params: 1,341,847
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

BATCH_SIZE = 64

checkpoint_path = 'SOL_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

callbacks = [checkpoint]
model.compile(
    loss='mean_squared_error',
    optimizer='adam'
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=BATCH_SIZE,
    shuffle=False,
    validation_split=0.1,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 00001: val_loss improved from inf to 0.01814, saving model to SOL_model.hdf5
# 9/9 [==============================] - 12s 245ms/step - loss: 0.0349 - val_loss: 0.0181
# Epoch 2/100
# 9/9 [==============================] - ETA: 0s - loss: 0.1109
# Epoch 00002: val_loss did not improve from 0.01814
# 9/9 [==============================] - 1s 79ms/step - loss: 0.1109 - val_loss: 0.0531
# Epoch 3/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 00003: val_loss improved from 0.01814 to 0.00261, saving model to SOL_model.hdf5
# 9/9 [==============================] - 1s 102ms/step - loss: 0.0129 - val_loss: 0.0026
# Epoch 4/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0923
# Epoch 00004: val_loss did not improve from 0.00261
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0923 - val_loss: 0.0087
# Epoch 5/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 00005: val_loss improved from 0.00261 to 0.00168, saving model to SOL_model.hdf5
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0708 - val_loss: 0.0017
# Epoch 6/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0149
# Epoch 00006: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0149 - val_loss: 0.0462
# Epoch 7/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 00007: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0374 - val_loss: 0.0044
# Epoch 8/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 00008: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0358 - val_loss: 0.0027
# Epoch 9/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00009: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 80ms/step - loss: 0.0053 - val_loss: 0.0636
# Epoch 10/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 00010: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0075 - val_loss: 0.0257
# Epoch 11/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 00011: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 82ms/step - loss: 0.0055 - val_loss: 0.0084
# Epoch 12/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00012: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0034 - val_loss: 0.0190
# Epoch 13/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00013: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0027 - val_loss: 0.0086
# Epoch 14/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00014: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0028 - val_loss: 0.0054
# Epoch 15/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00015: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 16/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00016: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 17/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00017: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0028 - val_loss: 0.0041
# Epoch 18/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00018: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 84ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 19/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00019: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 82ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 20/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00020: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 21/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 00021: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 82ms/step - loss: 0.0055 - val_loss: 0.0048
# Epoch 22/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 00022: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0093 - val_loss: 0.0037
# Epoch 23/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 00023: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0092 - val_loss: 0.0052
# Epoch 24/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 00024: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 25/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 00025: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0085 - val_loss: 0.0044
# Epoch 26/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00026: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0042 - val_loss: 0.0038
# Epoch 27/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00027: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 97ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 28/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00028: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0031 - val_loss: 0.0066
# Epoch 29/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00029: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 107ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 30/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00030: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 31/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 00031: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 103ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 32/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 00032: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 33/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00033: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 34/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00034: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 35/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00035: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 97ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 36/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00036: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 37/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00037: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 38/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00038: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 39/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00039: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 105ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 40/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00040: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 95ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 41/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 00041: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 42/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 00042: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 98ms/step - loss: 0.0078 - val_loss: 0.0064
# Epoch 43/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00043: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 44/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 00044: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 95ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 45/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 00045: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 96ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 46/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00046: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 98ms/step - loss: 0.0043 - val_loss: 0.0032
# Epoch 47/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 00047: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 48/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00048: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 49/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00049: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 50/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 00050: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 95ms/step - loss: 0.0034 - val_loss: 0.0051
# Epoch 51/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00051: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 101ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 52/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00052: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 53/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00053: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 54/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00054: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 55/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00055: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 56/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00056: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 113ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 57/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00057: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 97ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 58/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 00058: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 59/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 00059: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 60/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00060: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 61/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00061: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 111ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 62/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00062: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 97ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 63/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 00063: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 95ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 64/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 00064: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 103ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 65/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00065: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 99ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 66/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 00066: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 67/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00067: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 101ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 68/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00068: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 69/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00069: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 93ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 70/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00070: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 71/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 00071: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 108ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 72/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00072: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 106ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 73/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00073: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 111ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 74/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00074: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 89ms/step - loss: 0.0039 - val_loss: 0.0044
# Epoch 75/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00075: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 76/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00076: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 77/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00077: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 99ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 78/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00078: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 79/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 00079: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 107ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 80/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00080: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 81/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00081: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0027 - val_loss: 0.0036
# Epoch 82/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00082: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 110ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 83/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00083: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 84/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 00084: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 99ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 85/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00085: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 113ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 86/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 00086: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 87/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00087: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 106ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 88/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00088: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 98ms/step - loss: 0.0047 - val_loss: 0.0042
# Epoch 89/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00089: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 90/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00090: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0066 - val_loss: 0.0041
# Epoch 91/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 00091: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 104ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 92/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00092: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 93ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 93/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00093: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 94/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00094: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 95/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 00095: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 99ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 96/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00096: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 92ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 97/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 00097: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 107ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 98/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 00098: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 93ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 99/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00099: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 94ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 100/100
# 9/9 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00100: val_loss did not improve from 0.00168
# 9/9 [==============================] - 1s 101ms/step - loss: 0.0019 - val_loss: 0.0030

# %%
loss = history.history['loss']
epoch_count = range(1, len(loss) + 1)
plt.figure(figsize=(12,8))
plt.plot(epoch_count, loss, 'r--')
plt.legend(['Training Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
y_pred = model_from_saved_checkpoint.predict(X_test)

# %%
y_pred_transformed = scaler.inverse_transform(y_pred)
y_test_transformed = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(12, 8))
plt.plot(y_test_transformed, color='green', label='Real')
plt.plot(y_pred_transformed, color='red', label='Prediction')
plt.title('Solana Price Prediction')
plt.legend()
plt.show()

# %%
mean_absolute_error(y_pred_transformed, y_test_transformed)
# Out:
# 15.851078860410746
